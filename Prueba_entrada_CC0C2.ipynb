# %% [markdown]
# ### **Prueba de entrada - CC0C2**
#
# **Formato:** notebook individual
# **Duración sugerida:** 4 días
# **Lenguaje:** Python 3
# **Puntaje total:** **20 puntos**
#
# #### **Entrega obligatoria**
# Debes **subir un repositorio** con tus respuestas. El repositorio debe incluir como mínimo:
#
# - `Prueba_entrada_CC0C2_simple_v2.ipynb`
# - `src/`
# - `tests/`
# - `run_eval.py`
# - `README.md`
#
# #### **Regla importante**
# Puedes apoyarte en herramientas de IA, pero debes:
# 1. entender y poder explicar tu código,
# 2. probar lo que entregas,
# 3. dejar el repositorio ordenado y reproducible.
#
# #### **Objetivo**
# Verificar que llegas al curso con base útil en:
# - algoritmos para texto y retrieval,
# - desarrollo de software con harness,
# - seguridad mínima para sistemas con IA.
#
# #### **Distribución de puntaje**
# ##### **Parte 1. Algoritmos -8 puntos**
# - Problema 1. Chunking: 2 pts
# - Problema 2. Similaridad y top-k: 2 pts
# - Problema 3. Métricas de retrieval: 2 pts
# - Problema 4. Índice invertido simple: 2 pts
#
# ##### **Parte 2. Desarrollo de software/harness -7 puntos**
# - Harness reproducible: 4 pts
# - Tests: 2 pts
# - Explicación técnica: 1 pt
#
# ##### **Parte 3. Seguridad mínima para sistemas IA -5 puntos**
# - Sanitización de contexto: 2 pts
# - Redacción de PII: 1 pt
# - Prompt seguro + criterio: 2 pts

# %% [markdown]
# #### **Datos del estudiante**
#
# - Nombre:
# - Código:
# - Enlace al repositorio:
# - Herramientas de IA usadas:

# %% [markdown]
# ### **Parte 1. Algoritmos (8 puntos)**
#
# #### **Problema 1. Chunking (2 pts)**
# Implementa una función:
#
# ```python
# chunk_tokens(tokens, chunk_size, overlap)
# ```
#
# Debe:
# - dividir una lista de tokens en chunks,
# - usar overlap,
# - validar parámetros,
# - no perder tokens.
#
# #### **Tarea**
# 1. Implementa la función.
# 2. Explica en pocas líneas su complejidad temporal.
# 3. Muestra un ejemplo pequeño de entrada y salida.

# %%
def chunk_tokens(tokens, chunk_size, overlap):
    # Escribe tu solución aquí
    raise NotImplementedError

# %% [markdown]
# #### **Respuesta breve**
# Explica aquí:
# - complejidad temporal,
# - qué efecto tiene aumentar `chunk_size`,
# - qué efecto tiene aumentar `overlap`.

# %% [markdown]
# #### **Problema 2. Similaridad y top-k (2 pts)**
# Implementa:
#
# ```python
# cosine_similarity(a, b)
# top_k(query_vec, doc_vecs, k)
# ```
#
# #### **Tarea**
# 1. Calcula similaridad coseno entre dos vectores.
# 2. Retorna los índices de los `k` documentos más similares.
# 3. Maneja casos inválidos de manera razonable.

# %%
def cosine_similarity(a, b):
    # Escribe tu solución aquí
    raise NotImplementedError

def top_k(query_vec, doc_vecs, k):
    # Escribe tu solución aquí
    raise NotImplementedError

# %% [markdown]
# #### **Problema 3. Métricas de retrieval (2 pts)**
# Implementa:
#
# ```python
# recall_at_k(relevant_ids, predicted_ids, k)
# mrr(relevant_ids, predicted_ids)
# ```
#
# #### **Tarea**
# 1. Calcula `Recall@k`.
# 2. Calcula `MRR` para una consulta.
# 3. Explica en pocas líneas por qué `MRR` puede ser útil cuando importa la posición del primer resultado correcto.

# %%
def recall_at_k(relevant_ids, predicted_ids, k):
    # Escribe tu solución aquí
    raise NotImplementedError

def mrr(relevant_ids, predicted_ids):
    # Escribe tu solución aquí
    raise NotImplementedError

# %% [markdown]
# #### **Problema 4. Índice invertido simple (2 pts)**
# Implementa:
#
# ```python
# build_inverted_index(docs)
# search_index(query, docs, index)
# ```
#
# Donde:
# - `docs` es una lista de strings,
# - el índice debe mapear términos a ids de documentos,
# - la búsqueda debe devolver documentos ordenados por solapamiento de términos.
#
# #### **Tarea**
# 1. Normaliza texto de forma simple (por ejemplo: minúsculas y separación por espacios).
# 2. Construye el índice invertido.
# 3. Implementa una búsqueda léxica básica por conteo de términos compartidos.
# 4. Muestra un ejemplo con 3 a 5 documentos.

# %%
def normalize_text(text):
    # Escribe tu solución aquí
    raise NotImplementedError

def build_inverted_index(docs):
    # Escribe tu solución aquí
    raise NotImplementedError

def search_index(query, docs, index):
    # Escribe tu solución aquí
    raise NotImplementedError

# %% [markdown]
# ### **Parte 2. Desarrollo de software/harness (7 puntos)**
#
# Construye un harness mínimo para evaluar retrieval.
#
# #### **Requisitos del repositorio**
# Tu repositorio debe tener:
#
# ```text
# src/
# tests/
# run_eval.py
# README.md
# ```
#
# #### **Tarea principal (4 pts)**
# Implementa un comando como este:
#
# ```bash
# python run_eval.py --k 5 --seed 0
# ```
#
# El script debe:
# 1. cargar datos de ejemplo,
# 2. ejecutar retrieval,
# 3. calcular al menos `Recall@k` y/o `MRR`,
# 4. imprimir resultados de forma clara,
# 5. guardar una salida simple en `outputs/results.json`.
#
# #### **Tests mínimos (2 pts)**
# Agrega al menos **5 tests**:
# - 1 para chunking,
# - 1 para top-k,
# - 1 para métricas,
# - 1 para índice invertido,
# - 1 end-to-end.
#
# #### **Explicación técnica (1 pt)**
# Responde:
#
# **¿Qué diferencia hay entre una demo que funciona una vez y un sistema evaluable?**

# %% [markdown]
# #### **Respuesta breve**
# Escribe aquí tu respuesta.

# %% [markdown]
# ### **Parte 3. Seguridad mínima para sistemas IA (5 puntos)**
#
# Asume que algunos documentos del corpus son no confiables.
#
# #### **Problema 5. Sanitización simple (2 pts)**
# Implementa una función:
#
# ```python
# sanitize_context(text)
# ```
#
# La función debe detectar o marcar contenido sospechoso, por ejemplo:
# - instrucciones dentro del documento,
# - texto tipo "ignora las reglas",
# - intentos de cambiar la tarea del sistema.

# %%
def sanitize_context(text):
    # Escribe tu solución aquí
    raise NotImplementedError

# %% [markdown]
# #### **Problema 6. Redacción simple de PII (1 pt)**
# Implementa una función:
#
# ```python
# redact_pii(text)
# ```
#
# Debe ocultar al menos:
# - correos,
# - teléfonos.

# %%
def redact_pii(text):
    # Escribe tu solución aquí
    raise NotImplementedError

# %% [markdown]
# #### **Problema 7. Prompt seguro con contexto no confiable (2 pts)**
# Implementa una función:
#
# ```python
# build_safe_prompt(question, retrieved_chunks)
# ```
#
# La función debe construir un prompt que:
# 1. separe claramente **instrucciones del sistema** y **contexto recuperado**,
# 2. indique que el contexto recuperado es **no confiable**,
# 3. pida responder solo con base en evidencia relevante,
# 4. ignore instrucciones que aparezcan dentro de los documentos recuperados.
#
# No se pide llamar a un modelo, solo construir el prompt de forma clara y segura.

# %%
def build_safe_prompt(question, retrieved_chunks):
    # Escribe tu solución aquí
    raise NotImplementedError

# %% [markdown]
# #### **Respuestas breves**
# Responde en 4 a 6 líneas cada una:
#
# 1. ¿Por qué el contexto recuperado no debe tratarse como instrucción confiable?
# 2. ¿Por qué un sistema con IA necesita tests y no solo prompts?
# 3. ¿Qué riesgo aparece si el sistema recupera texto con datos privados?.

# %% [markdown]
# ### **Entregables finales**
#
# #### **Debes subir un repositorio con**:
# - este notebook resuelto,
# - código en `src/`,
# - tests en `tests/`,
# - `run_eval.py`,
# - `README.md` con instrucciones para ejecutar.
#
# #### Se evaluará
# - correctitud básica,
# - claridad del código,
# - organización del repositorio,
# - presencia de tests,
# - criterio mínimo de seguridad.
